# %%
import matplotlib.pyplot as plt

# Data for no stopping
no_stopping_epochs = list(range(46, 101))
no_stopping_accuracies = [
    97.14,
    98.05,
    97.90,
    97.98,
    98.21,
    98.33,
    98.51,
    98.46,
    98.28,
    98.65,
    98.60,
    98.37,
    98.54,
    94.27,
    98.04,
    98.60,
    98.53,
    98.61,
    98.35,
    98.37,
    98.47,
    98.32,
    98.21,
    98.42,
    98.28,
    98.40,
    98.23,
    98.39,
    98.46,
    98.32,
    98.60,
    98.09,
    98.26,
    98.37,
    98.49,
    98.42,
    98.21,
    98.44,
    94.62,
    98.42,
    98.47,
    98.58,
    98.09,
    98.21,
    98.28,
    97.97,
    98.46,
    98.56,
    98.47,
    98.19,
    97.91,
    97.86,
    98.58,
    98.47,
    98.51,
]

# Data for robust training
robust_training_epochs = list(range(46, 101))
robust_training_accuracies = [
    98.09,
    97.86,
    98.02,
    98.14,
    98.32,
    98.39,
    98.32,
    98.18,
    97.97,
    98.56,
    98.56,
    98.35,
    98.19,
    98.18,
    98.58,
    98.12,
    98.16,
    98.39,
    98.18,
    98.32,
    98.16,
    98.19,
    98.32,
    98.35,
    98.02,
    98.14,
    98.00,
    98.28,
    97.98,
    97.81,
    97.49,
    97.33,
    97.62,
    98.00,
    98.19,
    97.91,
    98.21,
    98.16,
    98.16,
    98.39,
    98.23,
    98.19,
    98.07,
    98.23,
    98.25,
    98.21,
    98.09,
    98.30,
    98.33,
    98.21,
    98.37,
    98.21,
    98.12,
    98.28,
    98.30,
]

# Optimal values for no stopping and robust training
no_stopping_optimal = max(no_stopping_accuracies)
robust_training_optimal = max(robust_training_accuracies)

# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(
    no_stopping_epochs,
    no_stopping_accuracies,
    label="Normal Training",
    marker="x",
    color="blue",
)
plt.plot(
    robust_training_epochs,
    robust_training_accuracies,
    label="Robust Training",
    marker="o",
    color="orange",
)

# Adding dash lines for optimal values, ending at each max point
plt.plot(
    [46, no_stopping_epochs[no_stopping_accuracies.index(no_stopping_optimal)]],
    [no_stopping_optimal, no_stopping_optimal],
    color="blue",
    linestyle="--",
)
plt.plot(
    [
        46,
        robust_training_epochs[
            robust_training_accuracies.index(robust_training_optimal)
        ],
    ],
    [robust_training_optimal, robust_training_optimal],
    color="orange",
    linestyle="--",
)

# Adding text for optimal values
plt.text(
    46, no_stopping_optimal + 0.1, "{:.2f}%".format(no_stopping_optimal), color="blue"
)
plt.text(
    46,
    robust_training_optimal - 0.4,
    "{:.2f}%".format(robust_training_optimal),
    color="orange",
)

# Adding labels and title
plt.xlabel("Epochs", fontsize=14, fontweight="bold")
plt.ylabel("Accuracy (%)", fontsize=14, fontweight="bold")
# plt.title("Accuracy over Epochs for No Stopping vs Robust Training")
plt.legend()
plt.grid(True)

# Showing max value on y-axis
plt.ylim(90, 100)
plt.xlim(46, 101)
plt.xticks(fontsize=12, fontweight="bold")
plt.yticks(fontsize=12, fontweight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for drop strategy
drop_strategy_epochs = list(range(46, 101))
drop_strategy_accuracies = [
    98.12,
    97.77,
    98.14,
    98.26,
    97.93,
    97.83,
    97.88,
    98.46,
    97.81,
    98.28,
    98.26,
    98.42,
    98.25,
    98.40,
    98.23,
    98.12,
    98.00,
    98.18,
    98.07,
    98.12,
    98.07,
    97.86,
    97.90,
    98.09,
    98.37,
    98.21,
    98.00,
    93.41,
    98.21,
    97.79,
    98.19,
    97.98,
    98.12,
    98.11,
    98.14,
    98.07,
    98.04,
    98.28,
    98.23,
    97.95,
    97.95,
    97.91,
    97.97,
    98.16,
    98.02,
    97.81,
    97.90,
    97.98,
    97.95,
    98.30,
    97.93,
    98.04,
    98.19,
    98.33,
    98.04,
]

# Data for move-to-unlabeled strategy
move_to_unlabeled_epochs = list(range(46, 101))
move_to_unlabeled_accuracies = [
    98.09,
    97.86,
    98.02,
    98.14,
    98.32,
    98.39,
    98.32,
    98.18,
    97.97,
    98.56,
    98.56,
    98.35,
    98.19,
    98.18,
    98.58,
    98.12,
    98.16,
    98.39,
    98.18,
    98.32,
    98.16,
    98.19,
    98.32,
    98.35,
    98.02,
    98.14,
    98.00,
    98.28,
    97.98,
    97.81,
    97.49,
    97.33,
    97.62,
    98.00,
    98.19,
    97.91,
    98.21,
    98.16,
    98.16,
    98.39,
    98.23,
    98.19,
    98.07,
    98.23,
    98.25,
    98.21,
    98.09,
    98.30,
    98.33,
    98.21,
    98.37,
    98.21,
    98.12,
    98.28,
    98.30,
]

# Optimal values for drop strategy and move-to-unlabeled strategy
drop_strategy_optimal = max(drop_strategy_accuracies)
move_to_unlabeled_optimal = max(move_to_unlabeled_accuracies)

# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(
    drop_strategy_epochs,
    drop_strategy_accuracies,
    label="Drop Strategy",
    marker="x",
    color="blue",
)
plt.plot(
    move_to_unlabeled_epochs,
    move_to_unlabeled_accuracies,
    label="Move-to-Unlabeled Strategy",
    marker="o",
    color="orange",
)

# Adding dash lines for optimal values, ending at each max point
plt.plot(
    [46, drop_strategy_epochs[drop_strategy_accuracies.index(drop_strategy_optimal)]],
    [drop_strategy_optimal, drop_strategy_optimal],
    color="blue",
    linestyle="--",
)
plt.plot(
    [
        46,
        move_to_unlabeled_epochs[
            move_to_unlabeled_accuracies.index(move_to_unlabeled_optimal)
        ],
    ],
    [move_to_unlabeled_optimal, move_to_unlabeled_optimal],
    color="orange",
    linestyle="--",
)

# Adding text for optimal values
plt.text(
    46,
    drop_strategy_optimal + 0.1,
    "{:.2f}%".format(drop_strategy_optimal),
    color="blue",
)
plt.text(
    46,
    move_to_unlabeled_optimal - 0.4,
    "{:.2f}%".format(move_to_unlabeled_optimal),
    color="orange",
)

# Adding labels and title
plt.xlabel("Epochs", fontsize=14, fontweight="bold")
plt.ylabel("Accuracy (%)", fontsize=14, fontweight="bold")
plt.legend()
plt.grid(True)

# Showing max value on y-axis
plt.ylim(90, 100)
plt.xlim(46, 101)

# Customize tick parameters
plt.xticks(fontsize=12, fontweight="bold")
plt.yticks(fontsize=12, fontweight="bold")
plt.show()
