# %%
import pickle

with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/checkpoint/memory_bank_net1.pkl",
    "rb",
) as f:
    memory_bank_net1 = pickle.load(f)
with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/checkpoint/memory_bank_net2.pkl",
    "rb",
) as f:
    memory_bank_net2 = pickle.load(f)

# %%
memory_bank_net1.memory[26000]
# Out:
# deque([], maxlen=10)

# %%
with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/outputs/07-13/04-04-42/memory_bank_net1_epoch_45.pkl",
    "rb",
) as f:
    amemory_bank_net1 = pickle.load(f)
with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/outputs/07-13/04-04-42/memory_bank_net2_epoch_45.pkl",
    "rb",
) as f:
    amemory_bank_net2 = pickle.load(f)

# %%
amemory_bank_net2.memory[23467]
# Out:
# deque([16, 12, 37, 13, 37, 28, 11, 20, 29], maxlen=10)

# %%
import pickle

with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/outputs/07-13/debug/06-49-50/memory_bank_net3_epoch_46.pkl",
    "rb",
) as f:
    bmemory_bank_net1 = pickle.load(f)

# %%
bmemory_bank_net1.memory
# Out:
# {0: deque([31, 31, 31, 31, 31, 31, 31, 31, 31, 31], maxlen=10),
#  1: deque([7, 7, 7, 7, 7, 7, 7, 7, 7, 7], maxlen=10),
#  2: deque([24, 24, 24, 24, 24, 24, 24, 24, 24, 24], maxlen=10),
#  3: deque([27, 27, 27, 27, 27, 27, 27, 27, 27, 27], maxlen=10),
#  4: deque([7, 7, 7, 7, 7, 7, 7, 7, 7, 7], maxlen=10),
#  5: deque([15, 15, 15, 15, 15, 15, 15, 15, 15, 15], maxlen=10),
#  6: deque([30, 30, 30, 30, 30, 30, 30, 30, 30, 30], maxlen=10),
#  7: deque([8, 8, 8, 8, 8, 8, 8, 8, 8, 8], maxlen=10),
#  8: deque([19, 19, 19, 19, 19, 19, 19, 19, 19, 19], maxlen=10),
#  9: deque([32, 32, 32, 32, 32, 32, 32, 32, 32, 32], maxlen=10),
#  10: deque([26, 26, 26, 26, 28, 28, 28, 31, 34, 26], maxlen=10),
#  11: deque([20, 20, 20, 20, 20, 20, 20, 20, 20, 20], maxlen=10),
#  12: deque([23, 23, 23, 23, 23, 23, 23, 23, 23, 23], maxlen=10),
#  13: deque([17, 17, 17, 17, 17, 17, 17, 17, 17, 17], maxlen=10),
#  14: deque([33, 33, 33, 33, 33, 33, 33, 33, 33, 33], maxlen=10),
# ...

# %%
import pickle

with open(
    "/hpc2hdd/home/mgong081/Projects/ClassificationNoisy/outputs/07-13/debug/06-49-50/memory_bank_net3_epoch_47.pkl",
    "rb",
) as f:
    cmemory_bank_net1 = pickle.load(f)

cmemory_bank_net1.memory
# Out:
# {0: deque([31, 31, 31, 31, 31, 31, 31, 31, 31, 31], maxlen=10),
#  1: deque([7, 7, 7, 7, 7, 7, 7, 7, 7, 7], maxlen=10),
#  2: deque([24, 24, 24, 24, 24, 24, 24, 24, 24, 24], maxlen=10),
#  3: deque([27, 27, 27, 27, 27, 27, 27, 27, 27, 27], maxlen=10),
#  4: deque([7, 7, 7, 7, 7, 7, 7, 7, 7, 7], maxlen=10),
#  5: deque([15, 15, 15, 15, 15, 15, 15, 15, 15, 15], maxlen=10),
#  6: deque([30, 30, 30, 30, 30, 30, 30, 30, 30, 30], maxlen=10),
#  7: deque([8, 8, 8, 8, 8, 8, 8, 8, 8, 8], maxlen=10),
#  8: deque([19, 19, 19, 19, 19, 19, 19, 19, 19, 19], maxlen=10),
#  9: deque([32, 32, 32, 32, 32, 32, 32, 32, 32, 32], maxlen=10),
#  10: deque([26, 26, 26, 28, 28, 28, 31, 34, 26, 26], maxlen=10),
#  11: deque([20, 20, 20, 20, 20, 20, 20, 20, 20, 20], maxlen=10),
#  12: deque([23, 23, 23, 23, 23, 23, 23, 23, 23, 23], maxlen=10),
#  13: deque([17, 17, 17, 17, 17, 17, 17, 17, 17, 17], maxlen=10),
#  14: deque([33, 33, 33, 33, 33, 33, 33, 33, 33, 33], maxlen=10),
# ...
